# %%
#import libraries
import pandas as pd
import numpy as np

# %%
location = "datasets/datasets/Kickstartercombo.csv"
df = pd.read_csv(location)
df.head()
# Out:
#    Unnamed: 0          ID                                               name  \
# 0           0  1000002330                    The Songs of Adelaide & Abullah
# 1           1  1000004038                                     Where is Hank?
# 2           2  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 3           3  1000011046  Community Film Project: The Art of Neighborhoo...
# 4           4  1000014025                               Monarch Espresso Bar
#
#   main_category        category country       state     goal  pledged  \
# 0    Publishing          Poetry      GB      failed   1000.0      0.0
# 1  Film & Video  Narrative Film      US      failed  45000.0    220.0
# 2         Music           Music      US      failed   5000.0      1.0
# 3  Film & Video    Film & Video      US    canceled  19500.0   1283.0
# 4          Food     Restaurants      US  successful  50000.0  52375.0
#
#   currency             launched             deadline  backers  usd pledged  \
# ...

# %%
dupe = df.duplicated() #creates list of True/False values
df[dupe] #shows rows where duplicated is True
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ID, name, main_category, category, country, state, goal, pledged, currency, launched, deadline, backers, usd pledged, usd_goal_real, usd_pledged_real]
# Index: []

# %%
df= df.drop('Unnamed: 0', 1)

# %%
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000004038                                     Where is Hank?
# 2  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 3  1000011046  Community Film Project: The Art of Neighborhoo...
# 4  1000014025                               Monarch Espresso Bar
#
#   main_category        category country       state     goal  pledged  \
# 0    Publishing          Poetry      GB      failed   1000.0      0.0
# 1  Film & Video  Narrative Film      US      failed  45000.0    220.0
# 2         Music           Music      US      failed   5000.0      1.0
# 3  Film & Video    Film & Video      US    canceled  19500.0   1283.0
# 4          Food     Restaurants      US  successful  50000.0  52375.0
#
#   currency             launched             deadline  backers  usd pledged  \
# ...

# %%
dupe = df.duplicated() #creates list of True/False values
df[dupe] #sh
# Out:
# Empty DataFrame
# Columns: [ID, name, main_category, category, country, state, goal, pledged, currency, launched, deadline, backers, usd pledged, usd_goal_real, usd_pledged_real]
# Index: []

# %%
df.columns
# Out:
# Index(['ID', 'name', 'main_category', 'category', 'country', 'state', 'goal',
#        'pledged', 'currency', 'launched', 'deadline', 'backers', 'usd pledged',
#        'usd_goal_real', 'usd_pledged_real'],
#       dtype='object')

# %%
df.dtypes
# Out:
# ID                    int64
# name                 object
# main_category        object
# category             object
# country              object
# state                object
# goal                float64
# pledged             float64
# currency             object
# launched             object
# deadline             object
# backers               int64
# usd pledged         float64
# usd_goal_real       float64
# usd_pledged_real    float64
# dtype: object

# %%
df.count()
# Out:
# ID                  702411
# name                702403
# main_category       702411
# category            702411
# country             702411
# state               702411
# goal                702411
# pledged             702411
# currency            702411
# launched            702411
# deadline            702411
# backers             702411
# usd pledged         694817
# usd_goal_real       378661
# usd_pledged_real    378661
# dtype: int64

# %%
df.isnull().sum()
# Out:
# ID                       0
# name                     8
# main_category            0
# category                 0
# country                  0
# state                    0
# goal                     0
# pledged                  0
# currency                 0
# launched                 0
# deadline                 0
# backers                  0
# usd pledged           7594
# usd_goal_real       323750
# usd_pledged_real    323750
# dtype: int64

# %%
missing_name = df.loc[df['name'].isnull()]
missing_name.head()
# Out:
#                 ID name main_category        category country      state  \
# 142830  1848699072  NaN  Film & Video  Narrative Film      US     failed
# 262901   634871725  NaN         Games     Video Games      GB     failed
# 265251   648853978  NaN        Design  Product Design      US  suspended
# 289847   796533179  NaN           Art        Painting      US     failed
# 490601  1848699072  NaN  Film & Video  Narrative Film      US     failed
#
#             goal  pledged currency             launched             deadline  \
# 142830  200000.0    100.0      USD  2012-01-01 12:35:00  2012-02-29 15:04:00
# 262901    2000.0    196.0      GBP  2012-12-19 23:57:00  2013-01-06 23:00:00
# 265251    2500.0      0.0      USD  2016-06-18 05:01:00  2016-07-18 05:01:00
# 289847   35000.0    220.0      USD  2011-11-06 23:55:00  2011-12-05 05:59:00
# 490601  200000.0    100.0      USD  2012-01-01 12:35:31           2012-02-29
#
#         backers  usd pledged  usd_goal_real  usd_pledged_real
# ...

# %%
df['main_category'].unique()
# Out:
# array(['Publishing', 'Film & Video', 'Music', 'Food', 'Design', 'Crafts',
#        'Games', 'Comics', 'Fashion', 'Theater', 'Art', 'Photography',
#        'Technology', 'Dance', 'Journalism', 'Graphic Novels'], dtype=object)

# %%
df['country'].unique()
# Out:
# array(['GB', 'US', 'CA', 'NO', 'AU', 'IT', 'DE', 'IE', 'ES', 'N,"0', 'MX',
#        'SE', 'FR', 'NL', 'NZ', 'CH', 'AT', 'BE', 'DK', 'HK', 'LU', 'SG',
#        'N,0"', 'JP'], dtype=object)

# %%
names= names.drop('main_category', 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-e44439285d3e> in <module>()
# ----> 1 names= names.drop('main_category', 1)
#       2 names
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# -> 3624                                  labels[mask])
# ...

# %%
names = df.loc[df['main_category'] == 'Technology']    
names
# Out:
#                 ID                                               name  \
# 57      1000245024                                         Safer Home
# 61      1000260691  Gizbee Unlimited Removable Storage for Your T...
# 62      1000261018  Diposta - liberating people from their postal ...
# 88       100039820                  Best Spray Bottle Ever - SureShot
# 94      1000427280  Fishtacular - The Ultimate Fishing Tool (Cance...
# 113     1000535116              Xi3: Help us Usher in the Post-PC Era
# 119     1000551777  Gantish - Online Reward Chart Creator for Parents
# 121     1000558429                   Sellegg start up classified site
# 130     1000590709                                 Musical Light Suit
# 135     1000624031                                Hangar 1 Foundation
# 137     1000629643  ODIN: Android 'Smart' Projector to Carry in Yo...
# 145     1000656794            VoxCube - 8x8x8 RGB LED chainable cubes
# ...

# %%
names
# Out:
#                 ID                                               name  \
# 57      1000245024                                         Safer Home
# 61      1000260691  Gizbee Unlimited Removable Storage for Your T...
# 62      1000261018  Diposta - liberating people from their postal ...
# 88       100039820                  Best Spray Bottle Ever - SureShot
# 94      1000427280  Fishtacular - The Ultimate Fishing Tool (Cance...
# 113     1000535116              Xi3: Help us Usher in the Post-PC Era
# 119     1000551777  Gantish - Online Reward Chart Creator for Parents
# 121     1000558429                   Sellegg start up classified site
# 130     1000590709                                 Musical Light Suit
# 135     1000624031                                Hangar 1 Foundation
# 137     1000629643  ODIN: Android 'Smart' Projector to Carry in Yo...
# 145     1000656794            VoxCube - 8x8x8 RGB LED chainable cubes
# ...

# %%
names.isnull().sum()
# Out:
# ID                      0
# name                    0
# category                0
# country                 0
# state                   0
# goal                    0
# pledged                 0
# currency                0
# launched                0
# deadline                0
# backers                 0
# usd pledged            14
# usd_goal_real       26161
# usd_pledged_real    26161
# dtype: int64

# %%
names['ratio']= (names.pledged*100)/names.goal
names.head()
# Out:
#             ID                                               name  category  \
# 57  1000245024                                         Safer Home  Hardware
# 61  1000260691  Gizbee Unlimited Removable Storage for Your T...   Gadgets
# 62  1000261018  Diposta - liberating people from their postal ...       Web
# 88   100039820                  Best Spray Bottle Ever - SureShot   Gadgets
# 94  1000427280  Fishtacular - The Ultimate Fishing Tool (Cance...      Apps
#
#    country     state      goal  pledged currency             launched  \
# 57      CA    failed   50000.0      0.0      CAD  2015-06-03 05:52:00
# 61      US  canceled   87000.0   2030.0      USD  2016-02-29 20:30:00
# 62      US    failed  100000.0    141.0      USD  2016-07-24 13:18:00
# 88      CA    failed   25000.0      3.0      CAD  2015-02-05 16:57:00
# 94      CA  canceled   50000.0  11336.0      CAD  2015-04-23 20:04:00
#
#                deadline  backers  usd pledged  usd_goal_real  \
# ...

# %%
names= names.drop('usd_goal_real', 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-c038ddbb81cf> in <module>()
# ----> 1 names= names.drop('usd_goal_real', 1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# -> 3624                                  labels[mask])
#    3625             indexer = indexer[~mask]
# ...

# %%
names.head()
# Out:
#             ID                                               name  category  \
# 57  1000245024                                         Safer Home  Hardware
# 61  1000260691  Gizbee Unlimited Removable Storage for Your T...   Gadgets
# 62  1000261018  Diposta - liberating people from their postal ...       Web
# 88   100039820                  Best Spray Bottle Ever - SureShot   Gadgets
# 94  1000427280  Fishtacular - The Ultimate Fishing Tool (Cance...      Apps
#
#    country     state      goal  pledged currency             launched  \
# 57      CA    failed   50000.0      0.0      CAD  2015-06-03 05:52:00
# 61      US  canceled   87000.0   2030.0      USD  2016-02-29 20:30:00
# 62      US    failed  100000.0    141.0      USD  2016-07-24 13:18:00
# 88      CA    failed   25000.0      3.0      CAD  2015-02-05 16:57:00
# 94      CA  canceled   50000.0  11336.0      CAD  2015-04-23 20:04:00
#
#                deadline  backers  usd pledged  usd_pledged_real      ratio
# ...

# %%
names= names.drop('usd_pledged_real', 1)

# %%
names= names.drop('currency', 1)

# %%
names.head()
# Out:
#             ID                                               name  category  \
# 57  1000245024                                         Safer Home  Hardware
# 61  1000260691  Gizbee Unlimited Removable Storage for Your T...   Gadgets
# 62  1000261018  Diposta - liberating people from their postal ...       Web
# 88   100039820                  Best Spray Bottle Ever - SureShot   Gadgets
# 94  1000427280  Fishtacular - The Ultimate Fishing Tool (Cance...      Apps
#
#    country     state      goal  pledged             launched  \
# 57      CA    failed   50000.0      0.0  2015-06-03 05:52:00
# 61      US  canceled   87000.0   2030.0  2016-02-29 20:30:00
# 62      US    failed  100000.0    141.0  2016-07-24 13:18:00
# 88      CA    failed   25000.0      3.0  2015-02-05 16:57:00
# 94      CA  canceled   50000.0  11336.0  2015-04-23 20:04:00
#
#                deadline  backers  usd pledged      ratio
# 57  2015-07-03 05:52:00        0     0.000000   0.000000
# ...

# %%
names.isnull().sum()
# Out:
# ID              0
# name            0
# category        0
# country         0
# state           0
# goal            0
# pledged         0
# launched        0
# deadline        0
# backers         0
# usd pledged    14
# ratio           0
# dtype: int64

# %%
names_no_missing = names.dropna()
names_no_missing
# Out:
#                 ID                                               name  \
# 57      1000245024                                         Safer Home
# 61      1000260691  Gizbee Unlimited Removable Storage for Your T...
# 62      1000261018  Diposta - liberating people from their postal ...
# 88       100039820                  Best Spray Bottle Ever - SureShot
# 94      1000427280  Fishtacular - The Ultimate Fishing Tool (Cance...
# 113     1000535116              Xi3: Help us Usher in the Post-PC Era
# 119     1000551777  Gantish - Online Reward Chart Creator for Parents
# 121     1000558429                   Sellegg start up classified site
# 130     1000590709                                 Musical Light Suit
# 135     1000624031                                Hangar 1 Foundation
# 137     1000629643  ODIN: Android 'Smart' Projector to Carry in Yo...
# 145     1000656794            VoxCube - 8x8x8 RGB LED chainable cubes
# ...

# %%
names_no_missing.isnull().sum()
# Out:
# ID             0
# name           0
# category       0
# country        0
# state          0
# goal           0
# pledged        0
# launched       0
# deadline       0
# backers        0
# usd pledged    0
# ratio          0
# dtype: int64

# %%
names_no_missing.head()
# Out:
#             ID                                               name  category  \
# 57  1000245024                                         Safer Home  Hardware
# 61  1000260691  Gizbee Unlimited Removable Storage for Your T...   Gadgets
# 62  1000261018  Diposta - liberating people from their postal ...       Web
# 88   100039820                  Best Spray Bottle Ever - SureShot   Gadgets
# 94  1000427280  Fishtacular - The Ultimate Fishing Tool (Cance...      Apps
#
#    country     state      goal  pledged             launched  \
# 57      CA    failed   50000.0      0.0  2015-06-03 05:52:00
# 61      US  canceled   87000.0   2030.0  2016-02-29 20:30:00
# 62      US    failed  100000.0    141.0  2016-07-24 13:18:00
# 88      CA    failed   25000.0      3.0  2015-02-05 16:57:00
# 94      CA  canceled   50000.0  11336.0  2015-04-23 20:04:00
#
#                deadline  backers  usd pledged      ratio
# 57  2015-07-03 05:52:00        0     0.000000   0.000000
# ...

# %%
names_no_missing['name'].unique()
# Out:
# array(['Safer Home',
#        'Gizbee\x99 Unlimited Removable Storage for Your Travel Photos',
#        'Diposta - liberating people from their postal mailbox.', ...,
#        'Ternary Computer System',
#        'How To Create a WordPress Website In 2017',
#        'Smartnanny®. The world’s first smart nanny.'], dtype=object)

# %%
names_no_missing.corr()
# Out:
#                    ID      goal   pledged   backers  usd pledged     ratio
# ID           1.000000  0.010904 -0.001414 -0.002049    -0.004481 -0.003859
# goal         0.010904  1.000000  0.003229 -0.001254     0.002797 -0.001165
# pledged     -0.001414  0.003229  1.000000  0.702886     0.833440  0.010495
# backers     -0.002049 -0.001254  0.702886  1.000000     0.673214  0.010335
# usd pledged -0.004481  0.002797  0.833440  0.673214     1.000000  0.008072
# ratio       -0.003859 -0.001165  0.010495  0.010335     0.008072  1.000000

# %%
names_no_missing= names_no_missing.drop('ID', 1)

# %%
names_no_missing.corr()
# Out:
#                  goal   pledged   backers  usd pledged     ratio
# goal         1.000000  0.003229 -0.001254     0.002797 -0.001165
# pledged      0.003229  1.000000  0.702886     0.833440  0.010495
# backers     -0.001254  0.702886  1.000000     0.673214  0.010335
# usd pledged  0.002797  0.833440  0.673214     1.000000  0.008072
# ratio       -0.001165  0.010495  0.010335     0.008072  1.000000

# %%
names_no_missing= names_no_missing.drop('usd pledged', 1)

# %%
names_no_missing.corr()
# Out:
#              goal   pledged   backers     ratio
# goal     1.000000  0.003229 -0.001254 -0.001165
# pledged  0.003229  1.000000  0.702886  0.010495
# backers -0.001254  0.702886  1.000000  0.010335
# ratio   -0.001165  0.010495  0.010335  1.000000

# %%
import statsmodels.formula.api as smf
import scipy.stats as stats
import matplotlib.pyplot as plt
import sklearn

# %matplotlib inline

# %%
result = smf.ols('ratio ~ goal + pledged + backers', data=names_no_missing).fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  ratio   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     2.522
# Date:                Fri, 07 Dec 2018   Prob (F-statistic):             0.0559
# Time:                        14:19:24   Log-Likelihood:            -6.5517e+05
# No. Observations:               58716   AIC:                         1.310e+06
# Df Residuals:                   58712   BIC:                         1.310e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    283.6693     71.209      3.984      0.000     144.100     423.239
# ...

# %%
names_no_missing.head()
# Out:
#                                                  name  category country  \
# 57                                         Safer Home  Hardware      CA
# 61  Gizbee Unlimited Removable Storage for Your T...   Gadgets      US
# 62  Diposta - liberating people from their postal ...       Web      US
# 88                  Best Spray Bottle Ever - SureShot   Gadgets      CA
# 94  Fishtacular - The Ultimate Fishing Tool (Cance...      Apps      CA
#
#        state      goal  pledged             launched             deadline  \
# 57    failed   50000.0      0.0  2015-06-03 05:52:00  2015-07-03 05:52:00
# 61  canceled   87000.0   2030.0  2016-02-29 20:30:00  2016-03-25 19:30:00
# 62    failed  100000.0    141.0  2016-07-24 13:18:00  2016-08-23 13:18:00
# 88    failed   25000.0      3.0  2015-02-05 16:57:00  2015-03-07 16:57:00
# 94  canceled   50000.0  11336.0  2015-04-23 20:04:00  2015-05-25 20:04:00
#
#     backers      ratio
# 57        0   0.000000
# 61       15   2.333333
# ...

# %%
modeldf = pd.get_dummies(data=names_no_missing, columns=['category','country', 'state'])
modeldf.head()
# Out:
#                                                  name      goal  pledged  \
# 57                                         Safer Home   50000.0      0.0
# 61  Gizbee Unlimited Removable Storage for Your T...   87000.0   2030.0
# 62  Diposta - liberating people from their postal ...  100000.0    141.0
# 88                  Best Spray Bottle Ever - SureShot   25000.0      3.0
# 94  Fishtacular - The Ultimate Fishing Tool (Cance...   50000.0  11336.0
#
#                launched             deadline  backers      ratio  \
# 57  2015-06-03 05:52:00  2015-07-03 05:52:00        0   0.000000
# 61  2016-02-29 20:30:00  2016-03-25 19:30:00       15   2.333333
# 62  2016-07-24 13:18:00  2016-08-23 13:18:00        3   0.141000
# 88  2015-02-05 16:57:00  2015-03-07 16:57:00        3   0.012000
# 94  2015-04-23 20:04:00  2015-05-25 20:04:00       19  22.672000
#
#     category_3D Printing  category_Apps  category_Camera Equipment  \
# ...

# %%
modeldf= modeldf.drop('launched', 1)

# %%
modeldf= modeldf.drop('deadline', 1)

# %%
modeldf= modeldf.drop('name', 1)

# %%
from sklearn.linear_model import LinearRegression
X = modeldf.drop('ratio', axis=1)

# %%
lm = LinearRegression()
lm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lm.fit(X, modeldf.ratio)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print('Estimated intercept coefficient:', lm.intercept_)
# Out:
# Estimated intercept coefficient: 87.929587748

# %%
print('Number of coefficients:', len(lm.coef_))
# Out:
# Number of coefficients: 46

# %%
pd.DataFrame(list(zip(X.columns, lm.coef_)), columns = ['features', 'estimatedCoefficients'])
# Out:
#                       features  estimatedCoefficients
# 0                         goal              -0.000003
# 1                      pledged               0.000081
# 2                      backers               0.039523
# 3         category_3D Printing            -198.065032
# 4                category_Apps              46.481024
# 5    category_Camera Equipment            -267.084415
# 6     category_DIY Electronics             958.410366
# 7   category_Fabrication Tools            -135.827648
# 8              category_Flight             -96.390320
# 9             category_Gadgets             134.570978
# 10           category_Hardware             476.603045
# 11        category_Makerspaces            -283.529037
# 12             category_Robots            -150.059820
# 13           category_Software               1.389260
# 14              category_Sound            -270.807569
# 15  category_Space Exploration            -309.274776
# ...

# %%
#test_size default = 0.25
X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(
    X, modeldf.ratio, test_size=0.33, random_state = 5)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (39339, 46)
# (19377, 46)
# (39339,)
# (19377,)

# %%
lm=LinearRegression()
lm.fit(X_train, Y_train)
pred_train = lm.predict(X_train)
pred_test = lm.predict(X_test)

# %%
print ('Fit a model X_train, and calculate MSE with Y_train:', np.mean((Y_train - lm.predict(X_train)) ** 2))
print ('Fit a model X_train, and calculate MSE with X_test, Y_test:', np.mean((Y_test - lm.predict(X_test)) ** 2))
# Out:
# Fit a model X_train, and calculate MSE with Y_train: 181385419.04562235
# Fit a model X_train, and calculate MSE with X_test, Y_test: 503676235.65544987
